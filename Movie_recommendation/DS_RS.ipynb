# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('/content/tmdb_movies.csv')
credits = pd.read_csv('/content/tmdb_credit.csv')

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# #*Feature Selection*

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew','budget','revenue','popularity']]
#movie_id	title	overview	genres	keywords	cast	crew	budget	revenue	popularity

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %% [markdown]
# #*InFormation extraction*

# %%
import ast

# %%
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# %%
movies.dropna(inplace=True)

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.sample(5)
# Out:
#       movie_id                         title  \
# 1176    257211                    The Intern
# 2753      9448                   The Big Hit
# 1810      9092  Snow White: A Tale of Terror
# 3541       321                Mambo Italiano
# 3369     11342                       Warlock
#
#                                                overview  \
# 1176  70-year-old widower Ben Whittaker has discover...
# 2753  Affable hit man Melvin Smiley is constantly be...
# 1810  Based somewhat more authentically on the Grimm...
# 3541  A sweet comic film about an Italian man who co...
# 3369  A warlock flees from the 17th to the 20th cent...
#
#                                      genres  \
# 1176                               [Comedy]
# 2753  [Action, Adventure, Comedy, Thriller]
# 1810                      [Fantasy, Horror]
# 3541                      [Comedy, Romance]
# 3369   [Adventure, Comedy, Fantasy, Horror]
#
#                                                keywords  \
# ...

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %% [markdown]
# #*DATA is REady to Work*

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movan = movies.copy()

# %%
movan_top_50 = movan.head(50)

# %% [markdown]
# #*Visualization*

# %%
import seaborn as sns
sns_plot = sns.barplot(data=movan_top_50.head(10),x='title',y='popularity')
# Rotate x-axis labels
sns_plot.set_xticklabels(sns_plot.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-87-a137607f5337>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   sns_plot.set_xticklabels(sns_plot.get_xticklabels(), rotation=90)
# [Text(0, 0, 'Avatar'),
#  Text(1, 0, "Pirates of the Caribbean: At World's End"),
#  Text(2, 0, 'Spectre'),
#  Text(3, 0, 'The Dark Knight Rises'),
#  Text(4, 0, 'John Carter'),
#  Text(5, 0, 'Spider-Man 3'),
#  Text(6, 0, 'Tangled'),
#  Text(7, 0, 'Avengers: Age of Ultron'),
#  Text(8, 0, 'Harry Potter and the Half-Blood Prince'),
#  Text(9, 0, 'Batman v Superman: Dawn of Justice')]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")


sns_plot = sns.lmplot(data=movan.head(1000), x='budget', y='revenue', ci=None, scatter_kws={'color': '#00FF00'}, line_kws={'color': 'red'})


sns_plot.set_axis_labels("Budget", "Revenue")
sns_plot.fig.suptitle("Scatter Plot with Regression Line")


plt.show()

# %%
sns.histplot(data=movan.head(100),x='popularity',bins=30)
# Out:
# <Axes: xlabel='popularity', ylabel='Count'>

# %%
sns.heatmap(movan[['budget', 'revenue', 'popularity']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sample_data = movan.sample(n=100, random_state=42)
sns.pairplot(sample_data[['budget', 'revenue', 'popularity']])
plt.suptitle('Pairplot of Budget, Revenue, and Popularity', y=1.02)
plt.show()

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title     budget     revenue  \
# 0     19995                                    Avatar  237000000  2787965087
# 1       285  Pirates of the Caribbean: At World's End  300000000   961000000
# 2    206647                                   Spectre  245000000   880674609
# 3     49026                     The Dark Knight Rises  250000000  1084939099
# 4     49529                               John Carter  260000000   284139100
#
#    popularity                                               tags
# 0  150.437577  In the 22nd century, a paraplegic Marine is di...
# 1  139.082615  Captain Barbossa, long believed to be dead, ha...
# 2  107.376788  A cryptic message from Bond’s past sends him o...
# 3  112.312950  Following the death of District Attorney Harve...
# 4   43.926995  John Carter is a war-weary, former military ca...

# %% [markdown]
# #*Pearson Correlation Recommendation*

# %%
from sklearn.feature_extraction.text import CountVectorizer
from scipy.stats import pearsonr

cv = CountVectorizer(max_features=5000, stop_words='english')
vector = cv.fit_transform(new['tags']).toarray()

def pearson_similarity(vec1, vec2):
    return pearsonr(vec1, vec2)[0]

def recommend(movie):
    index = new[new['title'] == movie].index[0]
    similarities = [(i, pearson_similarity(vector[index], vector[i])) for i in range(len(vector)) if i != index]
    similarities.sort(reverse=True, key=lambda x: x[1])
    for i in range(5):
        print(new.iloc[similarities[i][0]]['title'])

# Example usage
recommend("Avatar")
# Out:
# Titan A.E.
# Small Soldiers
# Ender's Game
# Aliens vs Predator: Requiem
# Independence Day
